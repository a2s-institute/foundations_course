# %% [markdown]
# # Python For Calculus
#
# ### Author: Santosh Muthireddy, Divin Devaiah
#
# # Requirements
# * Numpy
# * Sympy
# * Matplotlib
# * python3

# %%
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt

# %% [markdown]
# # Slope and Derivatives

# %%
#Generate data using linspace

data_x = np.linspace(0,10,100)

x = sp.Symbol('x')
# y = sp.Function(x)

y = 1 / (1+sp.exp(-(x-4)))
y
# Out:
# 1/(exp(4 - x) + 1)

# %%
# Substitute x values in y function and plot
data_y = [y.evalf(subs={x:i}) for i in data_x]

plt.figure()
plt.grid()
plt.xlabel("Time")
plt.ylabel("Distace")
plt.plot(data_x,data_y,label="distance")
plt.legend()

# %%
# First order derivative of function y
y_prime_1 = sp.Derivative(y)
# y_prime_1 = y.diff(x,1)
y_prime_1
# Out:
# Derivative(1/(exp(4 - x) + 1), x)

# %%
# Substitute values in y_prime and plot
data_y_prime = [y_prime_1.evalf(subs={x:i}) for i in data_x]

fig, ax1 = plt.subplots()
ax1.plot(data_x,data_y,label = "distance",color="tab:blue")
ax1.set_ylabel("Distance")
ax1.set_xlabel("Time")
ax1.set_ylim(0,1)
ax1.set_xlim(0,10)
ax2 = ax1.twinx()
ax2.plot(data_x,data_y_prime,label="velocity",color="tab:red")
ax2.set_ylabel("Velocity")
ax2.set_ylim(0,1)
ax2.set_xlim(0,10)
fig.tight_layout()

# %% [markdown]
# # Derivative of non-linear function

# %%
#Generate x data again using linspace 
data_x = np.linspace(0,10,100)

x = sp.Symbol("x")
y = sp.Function(x)

y = x**2
y
# Out:
# x**2

# %%
data_y = [y.evalf(subs={x:i}) for i in data_x]

plt.figure()
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(data_x,data_y,label="x")
plt.legend()

# %%
y_prime = y.diff(x,1)
y_prime
# Out:
# 2*x

# %%
data_y_prime = [y_prime.evalf(subs={x:i}) for i in data_x]

fig, ax1 = plt.subplots()
ax1.plot(data_x,data_y,label = "f(x)",color="tab:blue")
ax1.set_ylabel("f(x)")
ax1.set_xlabel("x")
ax1.set_xlim(0,10)
ax2 = ax1.twinx()
ax2.plot(data_x,data_y_prime,label="f_prime(x)",color="tab:red")
ax2.set_ylabel("f_prime(x)")
ax2.set_xlim(0,10)
fig.tight_layout()

# %% [markdown]
# # Dependent Systems

# %%
# u = Function(x)
x = sp.Symbol('x')
u = sp.Function(x)
u = x**3
u
# Out:
# x**3

# %%
# first order derivative du/dx
dudx = u.diff(x,1)
dudx

# %%
# v = Function(u)
u = sp.Symbol('u')
v = sp.Function(u)
v = u**2
v

# %%
# first order derivative dv/du
dvdu = v.diff(u)
dvdu

# %%
# substitute u=x^3
dvdu.subs(u,x**3)

# %%
# Chain rule: dv/dx = du/dx*dv/du
dvdx = dudx*dvdu
dvdx

# %%
# substitue u=x^3
dvdx.subs(u,x**3)

# %% [markdown]
# # Higher order derivatives

# %%
t = sp.Symbol('t')
distance = sp.Function(t)

distance = t**4
distance
# Out:
# t**4

# %%
# First order derivative
velocity = distance.diff(t)
velocity
# Out:
# 4*t**3

# %%
# Second order derivative
acceleration = distance.diff(t, 2)
acceleration
# Out:
# 12*t**2

# %%
data_t = np.linspace(0,5,100)

distance_subs = [distance.evalf(subs={t:i}) for i in data_t]
velocity_subs = [velocity.evalf(subs={t:i}) for i in data_t]
acceleration_subs = [acceleration.evalf(subs={t:i}) for i in data_t]

plt.plot(data_t,distance_subs,label='distance')
plt.plot(data_t,velocity_subs,label="velocity")
plt.plot(data_t,acceleration_subs,label="acceleration")
plt.legend()
plt.show()

# %% [markdown]
# # Integrals

# %%
data_x = np.linspace(0,10,100)
x = sp.Symbol('x')
y = sp.Function('y')(x)
# derivative of y w.r.t x
y_prime = sp.Derivative(y,x)
y = 1 / (1+sp.exp(-(x-4)))
print()
# y' = e^(4-x)/(1+e^(4-x))^2
eq = sp.Eq(y_prime, y_1)
eq
# Out:
# Eq(Derivative(y(x), x), 1/(exp(4 - x) + 1))

# %%
# solve the equation
sp.dsolve(eq)
# Out:
# Eq(y(x), C1 + log(exp(x) + exp(4)))

# %%
# Sloving the integral with intial value
sol = sp.dsolve(eq,ics={y.subs(x,0):})
sol
# Out:
#   File "<ipython-input-32-fa6e7ddf4b5b>", line 2
#     sol = sp.dsolve(eq,ics={y.subs(x,0):})
#                                         ^
# SyntaxError: invalid syntax

# %%
sp.simplify(sol)
