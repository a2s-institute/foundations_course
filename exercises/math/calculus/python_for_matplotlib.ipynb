# %% [markdown]
# # Introduction

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.(https://matplotlib.org/)
#
# When running python using the command line, the graphs are typically shown in a separate window. In a Jupyter notebook, we can simply output the graphs within the notebook itself by running the %matplotlib inline magic command.

# %%
# !pip install matplotlib

import matplotlib.pyplot as plt
# Out:
# ...
#      |████████████████████████████████| 9.4 MB 466 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 965 kB 2.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 557 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 295 kB 716 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.1 MB 1.3 MB/s eta 0:00:01
# ...

# %% [markdown]
# When running python using the command line, the graphs are typically shown in a separate window. In a Jupyter notebook, we can simply output the graphs within the notebook itself by running the %matplotlib inline magic command.(https://ipython.readthedocs.io/en/stable/interactive/plotting.html)

# %%
# %matplotlib inline

# %% [markdown]
# # Anatomy of a Plot

# %% [markdown]
# The Figure is the top-level container in this hierarchy. It is the overall window/page that everything is drawn on. You can have multiple independent figures and Figures can contain multiple Axes.
#
# Most plotting ocurs on an Axes. The axes is effectively the area that we plot data on and any ticks/labels/etc associated with it. Usually we'll set up an Axes with a call to subplot (which places Axes on a regular grid), so in most cases, Axes and Subplot are synonymous.
#
# Each Axes has an Xaxis and a Yaxis. These contain the ticks, tick locations, labels, etc.
#
# Further reading : https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py

# %% [markdown]
# ### Here we have intiated a figure with a single Axes

# %%
fig, ax = plt.subplots(2,2, figsize = (9, 5))  # a figure with a single Axes

print(fig)
# Out:
# Figure(900x500)

# %% [markdown]
# You can control the size of the figure through the figsize argument, which expects a tuple of (width, height) in inches.

# %%
fig, ax = plt.subplots(figsize = (9, 5))  #here te size of the figure is set by the figsize argument.

# %% [markdown]
# # Axes

# %% [markdown]
# All plotting is done with respect to an Axes. An Axes is made up of Axis objects and many other things. An Axes object must belong to a Figure (and only one Figure). Most commands you will ever issue will be with respect to this Axes object. With this Axes object, we can add title, labes for different axis, legends etc.
#
# In the above command, ax is the Axes object.

# %% [markdown]
# # Basic Plotting

# %% [markdown]
# Most plotting happens on an Axes. Therefore, if you're plotting something on an axes, then you'll use one of its methods.
# Plot draws points with lines connecting them.  scatter draws unconnected points, optionally scaled or colored by additional variables.

# %%
#making some data to plot
x = [1,2,3,4,5]
y = [2,4,6,8,10]

# plotting data
fig, ax = plt.subplots(figsize = (9, 5))  # Create a figure and an axes.


assert(len(x) == len(y))


# print(fig, ax)

ax.plot(x, y)  # Plot some data on the axes.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")
# print("hbfver")# Add a title to the axes.
plt.show()

# %% [markdown]
# # Multiple Axes

# %% [markdown]
# A figure can have more than one Axes on it.

# %%
#generating synthetic data
x = [1 ,2 ,3 ,4, 5]
x_2 = [1, 4, 9, 16, 25]

#creating figure with 2 axes. here the 2 axes are divided into 1 row and 2 columns
fig, axs = plt.subplots(1,2,figsize = (9, 5)) 

#plotting data on the first axes
axs[0].plot(x, x) 
axs[0].set_xlabel('x label')  # Add an x-label to the axes.
axs[0].set_ylabel('y label')  # Add a y-label to the axes.
axs[0].set_title("Simple Plot")  # Add a title to the axes.

#plotting data on the Second axes
axs[1].plot(x, x_2)  
axs[1].set_xlabel('x label  2')  # Add an x-label to the axes.
axs[1].set_ylabel('y label  2')  # Add a y-label to the axes.
axs[1].set_title("Simple Plot 2")  # Add a title to the axes.


plt.show()

# %% [markdown]
# # Legends

# %% [markdown]
# The simplest way to add a legend is to set a label on all lines, then just call the legend function.

# %%
#making some data to plot
x = [1 ,2 ,3 ,4, 5]
x_2 = [1, 4, 9, 16, 25]
x_3 = [1, 8, 27, 64, 125]

# plotting data

fig, ax = plt.subplots(figsize = (9, 5))  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x_2, color = 'purple', label='quadratic')  # Plot more data on the axes with purple color
ax.scatter(x, x_3, color = 'orange',marker = '*', label='cubic')
ax.plot(x, x_3, color = 'red', label='cubic line')# and some more with scatter, orange color, and different marker
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
# ax.legend()  # Calling the legend function
plt.show() #showing the plot.

# %% [markdown]
# # Non Linear Scales

# %%
#making some data to plot
x = [1 ,2 ,3 ,4, 5]

# plotting data
fig, ax = plt.subplots(figsize = (9, 5))  # Create a figure and an axes.
ax.plot(x, x)  # Plot some data on the axes.
ax.scatter(x,x)
ax.set_xlabel('log x')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_xscale('log') #setting the x axis to log
ax.set_yscale('log')
ax.scatter(x,x)
ax.set_title("Plot with x-axis in Log")  # Add a title to the axes.
plt.show()

#plotting data
fig, ax = plt.subplots(figsize = (9, 5))  # Create a figure and an axes.
ax.plot(x, x)  # Plot some data on the axes.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('log y')  # Add a y-label to the axes.
ax.set_yscale('log')
ax.set_title("Plot with x-axis in Log")  # Add a title to the axes.
plt.show()

# %% [markdown]
# # Saving the plot
#
# The figure can be saved by running the savefig option on the figure object

# %%
fig.savefig('file.pdf')

# %% [markdown]
# # 3D Projection

# %% [markdown]
# Plotting 3D graphs is quite straightforward. 3D plots are enabled by importng the mplot3d toolkit. Once this module have been imported then we can create a 3D axes by passing projection='3d' in any axes creation routine.

# %%
# https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html
from mpl_toolkits import mplot3d
import numpy as np
#creating figure
fig = plt.figure(figsize = (10, 6))
#creating 3d axes
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# # Data for three-dimensional scattered points
# zdata = 15 * np.random.random(100)
# xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
# ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
# ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
list_ = [5,2,2,6,3,4]
print([item*2 for item in list_] )

# examples for list comprehension

name_list = [
    [{"name":"waseem", "age" : 15},{"name": "Omar", "age": 20}],
    [{'name':'sankar', "age": 21},{'name':'ravi', "age": 21}]]

new =[person[0]["name"] for person in name_list]
print(new)
age_list = [person[0]["name"] for person in name_list if person[0]["age"] >= 20]
print(age_list)
age_list = [person["name"] for group_person in name_list for person in group_person if person["age"] >= 20]
print(age_list)
# Out:
# [10, 4, 4, 12, 6, 8]
# ['waseem', 'sankar']
# ['sankar']
# ['Omar', 'sankar', 'ravi']
